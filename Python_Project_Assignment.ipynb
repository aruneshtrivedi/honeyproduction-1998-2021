# %% [markdown]
# import the library<br>
# import numpy<br>
# import pandas<br>
# import matplotlib<br>
# import seaborn<br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading csv file into pandas dataframe
asn= pd.read_csv("honeyproduction 1998-2021.csv")
asn
# Out:
#              State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0          Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1          Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2         Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3       California  450000.0           83  37350000.0  12326000.0        0.62
# 4         Colorado   27000.0           72   1944000.0   1594000.0        0.70
# ..             ...       ...          ...         ...         ...         ...
# 980       Virginia    6000.0           40    240000.0     79000.0        8.23
# 981     Washington   96000.0           32   3072000.0   1206000.0        2.52
# 982  West Virginia    6000.0           43    258000.0    136000.0        4.80
# 983      Wisconsin   42000.0           47   1974000.0    750000.0        2.81
# 984        Wyoming   38000.0           58   2204000.0    242000.0        2.07
#
#       prodvalue  year
# ...

# %%
# finding the first 5 values
asn.head(5)
# Out:
#         State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1     Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2    Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3  California  450000.0           83  37350000.0  12326000.0        0.62
# 4    Colorado   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
# finding the bottom five values
asn.tail(5)
# Out:
#              State   numcol  yieldpercol  totalprod     stocks  priceperlb  \
# 980       Virginia   6000.0           40   240000.0    79000.0        8.23
# 981     Washington  96000.0           32  3072000.0  1206000.0        2.52
# 982  West Virginia   6000.0           43   258000.0   136000.0        4.80
# 983      Wisconsin  42000.0           47  1974000.0   750000.0        2.81
# 984        Wyoming  38000.0           58  2204000.0   242000.0        2.07
#
#      prodvalue  year
# 980  1975000.0  2021
# 981  7741000.0  2021
# 982  1238000.0  2021
# 983  5547000.0  2021
# 984  4562000.0  2021

# %%
# data type shape
asn.shape
# Out:
# (985, 8)

# %%
# find duplicate values
asn.duplicated().sum()
# Out:
# 0

# %%
# data frame  information
asn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %%
#data type name (int,float, object)
asn.dtypes
# Out:
# State           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
# null value found
asn.isna().any()
# Out:
# State          False
# numcol         False
# yieldpercol    False
# totalprod      False
# stocks         False
# priceperlb     False
# prodvalue      False
# year           False
# dtype: bool

# %%
#null value found and sum
asn.isna().sum()
# Out:
# State          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
# describe data 
asn.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     985.000000   985.000000  9.850000e+02  9.850000e+02  985.000000
# mean    62892.385787    58.402030  4.035132e+06  1.167187e+06    1.969594
# std     94163.791917    19.291695  6.752290e+06  2.088589e+06    1.177922
# min      2000.000000     3.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    45.000000  4.690000e+05  1.080000e+05    1.200000
# 50%     26000.000000    55.000000  1.488000e+06  3.600000e+05    1.700000
# 75%     68000.000000    70.000000  3.780000e+06  1.217000e+06    2.360000
# max    530000.000000   136.000000  4.641000e+07  1.380000e+07    8.230000
#
#           prodvalue         year
# count  9.850000e+02   985.000000
# mean   5.939911e+06  2009.291371
# std    9.806595e+06     6.962251
# min    1.620000e+05  1998.000000
# 25%    1.037000e+06  2003.000000
# 50%    2.409000e+06  2009.000000
# 75%    5.897000e+06  2015.000000
# ...

# %%
sns.pairplot(asn, kind='reg') # kind{‘scatter’, ‘kde’, ‘hist’, ‘reg’} 
plt.show()

# %% [markdown]
# ### Q1) How has honey production yield changed from 1998 to 2021?

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x='year',y='totalprod',data=asn,ci=None,color="black", marker="o")
plt.title("Honey production yield changed from 1998 to 2021",size=18)
plt.xlabel("Year",size=14,color="red")
plt.ylabel("Honey Production yieldpercol",size=14,color="red")
plt.xticks(rotation=60)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(asn['year'],asn['totalprod'])
plt.title('Production vs year',fontsize=18,color='black')
plt.xlabel('Year',fontsize=15,color='red')
plt.ylabel('Total_ Production',fontsize=15,color='red')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q2) Over time, what are the major production trends across the states?

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(18,7)})
sns.set_context('paper',font_scale=1.5,rc={'grid.linewidth':0.5})
ax=sns.pointplot(data=asn,x='year',y='totalprod',hue='State',ci=None)
ax.set_ylabel("Total Production")
ax.set_title("Production trends across the states ",size=18)
plt.xticks(rotation=60)
plt.legend(bbox_to_anchor=(1,1))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,10))  #setting figure size
sns.catplot(data=asn,x='year', y='totalprod', col='State', kind='strip',height=4,col_wrap=8) 
 #using catplot for accurate visualization of the production trends across the state
plt.show() # showing the plot

# %%
df2=asn.groupby(['year'])[['yieldpercol','numcol']].sum().reset_index()
df2
# Out:
#     year  yieldpercol     numcol
# 0   1998         3008  2621000.0
# 1   1999         2815  2637000.0
# 2   2000         2906  2604000.0
# 3   2001         2840  2542000.0
# 4   2002         2939  2565000.0
# 5   2003         2752  2591000.0
# 6   2004         2657  2539000.0
# 7   2005         2635  2394000.0
# 8   2006         2536  2378000.0
# 9   2007         2426  2428000.0
# 10  2008         2501  2326000.0
# 11  2009         2154  2472000.0
# 12  2010         2251  2666000.0
# 13  2011         2191  2466000.0
# 14  2012         2207  2509000.0
# 15  2013         2066  2607000.0
# 16  2014         2294  2709000.0
# 17  2015         2213  2630000.0
# 18  2016         2163  2740000.0
# 19  2017         2127  2635000.0
# 20  2018         1935  2767000.0
# 21  2019         2042  2782000.0
# 22  2020         2000  2673000.0
# 23  2021         1868  2668000.0

# %% [markdown]
# ### Q3) Does the data show any trends in terms of the number of honey-producing colonies and yield per colony before 2006, which was when concern over Colony Collapse Disorder spread nationwide?

# %%
df_year=(asn[(asn['year']<2006)])
df_year.tail()
# Out:
#              State   numcol  yieldpercol  totalprod     stocks  priceperlb  \
# 338       Virginia   8000.0           37   296000.0    59000.0        2.20
# 339     Washington  51000.0           55  2805000.0  1935000.0        1.01
# 340  West Virginia   8000.0           51   408000.0   102000.0        1.29
# 341      Wisconsin  64000.0           83  5312000.0  2922000.0        1.14
# 342        Wyoming  40000.0           56  2240000.0   291000.0        0.89
#
#      prodvalue  year
# 338   651000.0  2005
# 339  2833000.0  2005
# 340   526000.0  2005
# 341  6056000.0  2005
# 342  1994000.0  2005

# %%
df1=df_year.groupby(['year'])[['yieldpercol','numcol']].sum().reset_index()
df1
# Out:
#    year  yieldpercol     numcol
# 0  1998         3008  2621000.0
# 1  1999         2815  2637000.0
# 2  2000         2906  2604000.0
# 3  2001         2840  2542000.0
# 4  2002         2939  2565000.0
# 5  2003         2752  2591000.0
# 6  2004         2657  2539000.0
# 7  2005         2635  2394000.0

# %%
sea=sns.FacetGrid(df_year,col='year')
sea.map(sns.scatterplot,'yieldpercol','numcol')
plt.show()

# %%
plt.plot(df1['year'],df1['yieldpercol'],color='blue')
plt.plot(df1['year'],df1['numcol'],color='maroon',lw=3,marker='o')
plt.xlabel('Year',color='blue')
plt.ylabel('Number of colony',color='blue')
plt.title('year wise yield per colony and number of colony',color='blue',size=21)
plt.grid()
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(14,5))  # nrows = 1, ncols =2
# ax1 is the name of plot1
# ax2 is the name of plot2

ax1.bar(asn['year'],asn['numcol'],color='orange',edgecolor='black')
ax1.set_title('Total honey production every Year')
ax1.set_ylabel('Sum of total production')
ax1.set_xlabel('Year')


ax2.bar(asn['year'],asn['yieldpercol'],color='blue')
ax2.set_title(' Total honey production value every Year')
ax2.set_xlabel('Year')
ax2.set_ylabel('Total production value')      
ax2.grid()

plt.show()

# %% [markdown]
# ### Q4) Are there any patterns that can be observed between total honey production and the value of production every year?

# %%
sns.set(rc={'figure.figsize':(10,5)})   
sns.scatterplot(data=asn,x='totalprod',y='prodvalue',hue='year')
plt.show()

# %%
d_f=asn.groupby(['year']).sum()
d_f.head(5)
# Out:
#                                                   State     numcol  \
# year
# 1998  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2621000.0
# 1999  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2637000.0
# 2000  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2604000.0
# 2001  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2542000.0
# 2002  AlabamaArizonaArkansasCaliforniaColoradoFlorid...  2565000.0
#
#       yieldpercol    totalprod      stocks  priceperlb    prodvalue
# year
# 1998         3008  219519000.0  80565000.0       35.80  146091000.0
# 1999         2815  202387000.0  78390000.0       34.58  123657000.0
# 2000         2906  219558000.0  84956000.0       34.03  131568000.0
# 2001         2840  185748000.0  64764000.0       40.12  132282000.0
# 2002         2939  171265000.0  39177000.0       60.34  227302000.0

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(14,5))  # nrows = 1, ncols =2
# ax1 is the name of plot1
# ax2 is the name of plot2

ax1.bar(df1.index,df1['totalprod'],color='orange',edgecolor='black')
ax1.set_title('Sum of total honey production every Year')
ax1.set_ylabel('Sum of total production')
ax1.set_xlabel('Year')


ax2.plot(df1.index,df1['prodvalue'],color='blue',marker='d',markersize=8)
ax2.set_title(' Total honey production value every Year')
ax2.set_xlabel('Year')
ax2.set_ylabel('sum of production value')      
ax2.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'totalprod'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 5
#       1 fig, (ax1,ax2) = plt.subplots(1,2,figsize=(14,5))  # nrows = 1, ncols =2
# ...

# %% [markdown]
# ### Q5) How has the value of production, which in some sense could be tied to demand, changed every year?

# %%
df=asn.groupby(['year'])[['totalprod','stocks','numcol','yieldpercol','prodvalue']].sum().reset_index()
df.head()

# %%
df['consumption']=df['totalprod'] - df['stocks']
df.head()

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('whitegrid')
sns.set_context('poster',font_scale=0.5,rc={'grid.linewidth':0.7})
sns.set_palette('Purples_r')
sns.lineplot(data=df,x='year',y='prodvalue',marker='o',ci=None)
sns.lineplot(data=df,x='year',y='consumption',marker='>',ci=None)
plt.xlabel('year',size=12)
plt.ylabel('values for production and consumption',size=12)
plt.xticks(df['year'],rotation=45)
plt.title('production value tied up with demand year wise',color='black',size=18)
plt.show()

# %% [markdown]
# ### Q6) Construct the related plots using Seaborn and Matplot apply customization and derive insights from the visualization.

# %%
plt.figure(figsize=(30,30))
sns.barplot(x='totalprod',y='State',data=asn.sort_values("totalprod",ascending=False),label='production per state',color='blue')
sns.barplot(x='stocks',y='State',data=asn.sort_values("totalprod",ascending=False),label='stocks per state',color='pink')
plt.legend(ncol=2)
plt.title("Honey production vs state",size=28)
plt.show()

# %% [markdown]
# practice

# %%
asn_sorted=asn.sort_values(['totalprod','stocks'])

# %%
plt.figure(figsize=(40,15))
plt.bar(asn_sorted['State'],asn_sorted['totalprod'],color='cyan',label='totalproduction per state')
plt.bar(asn_sorted['State'],asn_sorted['stocks'],color='orange',label='totalproduction per stocks',
        bottom=asn_sorted['totalprod'])
plt.title('State wise report of production',size=45)
plt.xlabel('State',size=25)
plt.ylabel('Total prod and stocks',size=25)
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
maxp=df.groupby(['year'])['totalprod'].sum()
asn_sorted=asn.sort_values(['totalprod']).sum()
r2=maxp.head()
r2

# %%
plt.figure(figsize=(5,5))
plt.pie(x = r2.values,labels=r2.index,
        colors=['yellow','blue','red','green','cyan'],autopct='%.3f%%',
       explode=(0,0,0.1,0,0),shadow=True,counterclock=False)
plt.title(' Top 5 Year of  Total Honey Production',fontsize=15,color='blue')
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(25, 15))

fig.suptitle('US Honey Production 1995-2021 - distribution of variables', fontsize='xx-large', y=0.93)

sns.histplot(ax=axes[0, 0], data=asn, x='numcol')
sns.histplot(ax=axes[0, 1], data=asn, x='yieldpercol')
sns.histplot(ax=axes[0, 2], data=asn, x='totalprod')
sns.histplot(ax=axes[1, 0], data=asn, x='stocks')
sns.histplot(ax=axes[1, 1], data=asn, x='prodvalue')
sns.histplot(ax=axes[1, 2], data=asn, x='priceperlb')
